# %%
#http://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ###### Selection Options
# There’s three main options to achieve the selection and indexing activities in Pandas, which can be confusing. The three selection cases and methods covered in this post are:
#
# Selecting data by row numbers (.iloc)
# Selecting data by label or by a conditional statment (.loc)
# Selecting in a hybrid approach (.ix)

# %%
data= pd.read_csv('https://s3-eu-west-1.amazonaws.com/shanebucket/downloads/uk-500.csv')

# %%
data.shape
# Out:
# (500, 11)

# %%
data.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web
# 0  http://www.alandrosenburgcpapc.co.uk
# 1     http://www.capgeminiamerica.co.uk
# 2      http://www.elliottjohnwesq.co.uk
# 3          http://www.mcmahanbenl.co.uk
# 4        http://www.champagneroom.co.uk

# %% [markdown]
# 1. Selecting pandas data using “iloc”
# The iloc indexer for Pandas Dataframe is used for integer-location based indexing / selection by position.
#
# The iloc indexer syntax is data.iloc[<row selection>, <column selection>], which is sure to be a source of confusion for R users. “iloc” in pandas is used to select rows and columns by number, in the order that they appear in the data frame. You can imagine that each row has a row number from 0 to the total rows (data.shape[0])  and iloc[] allows selections based on these numbers. The same applies for columns (ranging from 0 to data.shape[1] )
#
# There are two “arguments” to iloc – a row selector, and a column selector.  For example:

# %%
data.columns
# Out:
# Index(['first_name', 'last_name', 'company_name', 'address', 'city', 'county',
#        'postal', 'phone1', 'phone2', 'email', 'web'],
#       dtype='object')

# %%
 #Single selections using iloc and DataFrame
# Rows:

# %%
data.iloc[0]# First row of data
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# Name: 0, dtype: object

# %%
data.iloc[1]
# Out:
# first_name                                   Evan
# last_name                               Zigomalas
# company_name                   Cap Gemini America
# address                               5 Binney St
# city                                   Abbey Ward
# county                            Buckinghamshire
# postal                                   HP11 2AX
# phone1                               01937-864715
# phone2                               01714-737668
# email                    evan.zigomalas@gmail.com
# web             http://www.capgeminiamerica.co.uk
# Name: 1, dtype: object

# %%
data.iloc[-1]# last row of data
# Out:
# first_name                                               Mi
# last_name                                            Richan
# company_name                 Nelson Wright Haworth Golf Crs
# address                                     6 Norwood Grove
# city                                      Tanworth-in-Arden
# county                                         Warwickshire
# postal                                              B94 5RZ
# phone1                                         01451-785624
# phone2                                         01202-738406
# email                                        mi@hotmail.com
# web             http://www.nelsonwrighthaworthgolfcrs.co.uk
# Name: 499, dtype: object

# %%
data.iloc[:,0]# first column of data
# Out:
# 0          Aleshia
# 1             Evan
# 2           France
# 3          Ulysses
# 4           Tyisha
# 5             Eric
# 6             Marg
# 7          Laquita
# 8             Lura
# 9           Yuette
# 10        Fernanda
# 11     Charlesetta
# 12        Corrinne
# 13          Niesha
# 14          Rueben
# 15         Michell
# 16           Edgar
# 17          Dewitt
# 18        Charisse
# 19             Mee
# 20           Peter
# 21         Octavio
# 22          Martha
# 23         Tamesha
# 24            Tess
# 25         Leonard
# 26        Svetlana
# 27             Pok
# 28       Augustine
# 29           Karma
#           ...
# 470           Tony
# 471            Val
# 472            Mel
# 473       Isabella
# 474         Erasmo
# 475          Ivory
# 476         Nikita
# 477          Aleta
# 478           Owen
# 479        Pauline
# 480        Tijuana
# 481          Ahmad
# 482         Jamika
# 483        Derrick
# 484     Jacquelyne
# 485        Zachary
# 486         Sophia
# 487       Isabelle
# 488         Ronnie
# 489       Krystina
# 490         Rosita
# 491           Huey
# 492         Elbert
# 493           Pura
# 494         Alesia
# 495          Avery
# 496           Reid
# 497      Charlette
# 498      Celestina
# 499             Mi
# Name: first_name, dtype: object

# %%
data.iloc[:,1]
# Out:
# 0      Tomkiewicz
# 1       Zigomalas
# 2         Andrade
# 3       Mcwalters
# 4          Veness
# 5           Rampy
# 6        Grasmick
# 7           Hisaw
# 8        Manzella
# 9          Klapec
# 10         Writer
# 11            Erm
# 12          Jaret
# 13          Bruch
# 14      Gastellum
# 15      Throssell
# 16          Kanne
# 17          Julio
# 18       Spinello
# 19       Lapinski
# 20      Gutierres
# 21      Salvadore
# 22        Teplica
# 23         Veigel
# 24          Sitra
# 25         Kufner
# 26         Tauras
# 27       Molaison
# 28       Growcock
# 29         Quarto
#           ...
# 470    Diazdeleon
# 471        Villot
# 472      Picciuto
# 473    Piatkowski
# 474          Rhea
# 475       Lohrenz
# 476         Walka
# 477        Ligons
# 478       Jentzen
# 479         Fling
# 480      Machalek
# 481       Alsaqri
# 482        Conoly
# 483       Dolloff
# 484       Reibman
# 485    Freeburger
# 486       Gaucher
# 487          Kono
# 488       Brigman
# 489    Schlabaugh
# 490     Ausdemore
# 491       Stancil
# 492       Fiorino
# 493       Manciel
# 494         Katie
# 495          Veit
# 496       Euresti
# 497      Brenning
# 498         Keeny
# 499        Richan
# Name: last_name, dtype: object

# %%
data.iloc[:,-1]
# Out:
# 0              http://www.alandrosenburgcpapc.co.uk
# 1                 http://www.capgeminiamerica.co.uk
# 2                  http://www.elliottjohnwesq.co.uk
# 3                      http://www.mcmahanbenl.co.uk
# 4                    http://www.champagneroom.co.uk
# 5              http://www.thompsonmichaelcesq.co.uk
# 6          http://www.wranglehillautoauctslvg.co.uk
# 7              http://www.incommunicationsinc.co.uk
# 8                    http://www.bizerbausainc.co.uk
# 9                         http://www.maxvideo.co.uk
# 10                 http://www.krassociatesinc.co.uk
# 11                    http://www.cainjohnmesq.co.uk
# 12                 http://www.soundvisioncorp.co.uk
# 13            http://www.rowleyhansellpetetin.co.uk
# 14     http://www.industrialengineeringassocs.co.uk
# 15                 http://www.weissspirtguyer.co.uk
# 16               http://www.crowankennethwesq.co.uk
# 17              http://www.rittenhousemotorco.co.uk
# 18              http://www.modernplasticscorp.co.uk
# 19           http://www.gallowayelectriccoinc.co.uk
# 20         http://www.niagaracustombuiltmfgco.co.uk
# 21             http://www.practicalperiphrals.co.uk
# 22              http://www.curtinpatriciamesq.co.uk
# 23                 http://www.wilhelmjamesejr.co.uk
# 24                      http://www.smartsigns.co.uk
# 25       http://www.arcticstardistributinginc.co.uk
# 26            http://www.lensbowergregorylesq.co.uk
# 27             http://www.portalmetalproducts.co.uk
# 28                  http://www.lynemacliffcpa.co.uk
# 29                    http://www.jcsmachinery.co.uk
#                            ...
# 470               http://www.dillingharrisinc.co.uk
# 471             http://www.horizonairmagazine.co.uk
# 472                  http://www.avantelimited.co.uk
# 473              http://www.millerwilliameiii.co.uk
# 474                http://www.martinmorrissey.co.uk
# 475                  http://www.autobodycolor.co.uk
# 476                 http://www.fredanthonyesq.co.uk
# 477           http://www.advantagebookkeeping.co.uk
# 478            http://www.capitalfastenersinc.co.uk
# 479       http://www.cumberlandvacuumproducts.co.uk
# 480             http://www.schwartzthomaseesq.co.uk
# 481      http://www.allianceconstructioncoinc.co.uk
# 482                 http://www.kellerraymondc.co.uk
# 483          http://www.prototekmanufacturing.co.uk
# 484              http://www.greatclipsforhair.co.uk
# 485                 http://www.countrykitchen.co.uk
# 486                  http://www.tcesystemsinc.co.uk
# 487      http://www.rockspringspetroleumequip.co.uk
# 488                  http://www.howardjohnson.co.uk
# 489            http://www.harrisoldsmobileinc.co.uk
# 490                 http://www.jurdemscottesq.co.uk
# 491                   http://www.lindnerfunds.co.uk
# 492               http://www.donaldgnelsonesq.co.uk
# 493                  http://www.ciainspection.co.uk
# 494         http://www.nelsonstrmtpestcntrlco.co.uk
# 495       http://www.plazagourmetdelicatessen.co.uk
# 496              http://www.fitzgeraldedwardj.co.uk
# 497                http://www.fureyassociates.co.uk
# 498          http://www.bfgfederalcreditunion.co.uk
# 499     http://www.nelsonwrighthaworthgolfcrs.co.uk
# Name: web, dtype: object

# %%
#Multiple columns and rows can be selected together using the .iloc indexer.
# Multiple row and column selections using iloc and DataFrame
data.iloc[0:5]#first 5 rowsand all the columns of the dataframe
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web
# 0  http://www.alandrosenburgcpapc.co.uk
# 1     http://www.capgeminiamerica.co.uk
# 2      http://www.elliottjohnwesq.co.uk
# 3          http://www.mcmahanbenl.co.uk
# 4        http://www.champagneroom.co.uk

# %%
data.iloc[:,0:2]# all rows and first 2 columns
# Out:
#       first_name   last_name
# 0        Aleshia  Tomkiewicz
# 1           Evan   Zigomalas
# 2         France     Andrade
# 3        Ulysses   Mcwalters
# 4         Tyisha      Veness
# 5           Eric       Rampy
# 6           Marg    Grasmick
# 7        Laquita       Hisaw
# 8           Lura    Manzella
# 9         Yuette      Klapec
# 10      Fernanda      Writer
# 11   Charlesetta         Erm
# 12      Corrinne       Jaret
# 13        Niesha       Bruch
# 14        Rueben   Gastellum
# 15       Michell   Throssell
# 16         Edgar       Kanne
# 17        Dewitt       Julio
# 18      Charisse    Spinello
# 19           Mee    Lapinski
# 20         Peter   Gutierres
# 21       Octavio   Salvadore
# 22        Martha     Teplica
# 23       Tamesha      Veigel
# 24          Tess       Sitra
# 25       Leonard      Kufner
# 26      Svetlana      Tauras
# 27           Pok    Molaison
# 28     Augustine    Growcock
# 29         Karma      Quarto
# ..           ...         ...
# 470         Tony  Diazdeleon
# 471          Val      Villot
# 472          Mel    Picciuto
# 473     Isabella  Piatkowski
# 474       Erasmo        Rhea
# 475        Ivory     Lohrenz
# 476       Nikita       Walka
# 477        Aleta      Ligons
# 478         Owen     Jentzen
# 479      Pauline       Fling
# 480      Tijuana    Machalek
# 481        Ahmad     Alsaqri
# 482       Jamika      Conoly
# 483      Derrick     Dolloff
# 484   Jacquelyne     Reibman
# 485      Zachary  Freeburger
# 486       Sophia     Gaucher
# 487     Isabelle        Kono
# 488       Ronnie     Brigman
# 489     Krystina  Schlabaugh
# 490       Rosita   Ausdemore
# 491         Huey     Stancil
# 492       Elbert     Fiorino
# 493         Pura     Manciel
# 494       Alesia       Katie
# 495        Avery        Veit
# 496         Reid     Euresti
# 497    Charlette    Brenning
# 498    Celestina       Keeny
# 499           Mi      Richan
#
# [500 rows x 2 columns]

# %%
data.iloc[487]# note the return is not the same as data.loc
# Out:
# first_name                                        Isabelle
# last_name                                             Kono
# company_name                  Rock Springs Petroleum Equip
# address                                 4920 Fazakerley Rd
# city                               Plymstock Dunstone Ward
# county                                               Devon
# postal                                             PL9 8RD
# phone1                                        01552-682601
# phone2                                        01953-816728
# email                              isabelle.kono@yahoo.com
# web             http://www.rockspringspetroleumequip.co.uk
# Name: 487, dtype: object

# %%
data.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
#data[['first_name','county', 'postal']]# will bring in all the rows
# Out:
#    first_name        county    postal
# 0     Aleshia          Kent   CT2 7PP
# 3     Ulysses  Lincolnshire  DN36 5RP
# 6        Marg   Southampton  SO14 3TY
# 24       Tess   West Sussex  PO19 1RH

# %%
data.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame (county -> phone1).
# Out:
#             county    postal        phone1
# 0             Kent   CT2 7PP  01835-703597
# 1  Buckinghamshire  HP11 2AX  01937-864715
# 2      Bournemouth   BH6 3BE  01347-368222
# 3     Lincolnshire  DN36 5RP  01912-771311
# 4    West Midlands   B70 9DT  01547-429341

# %% [markdown]
# Note that .iloc returns a Pandas Series when one row is selected, and a Pandas DataFrame when multiple rows are selected, or if any column in full is selected. To counter this, pass a single-valued list if you require DataFrame output.
# When using .loc, or .iloc, you can control the output format by passing lists or single values to the selectors.
# When using .loc, or .iloc, you can control the output format by passing lists or single values to the selectors.

# %% [markdown]
# When selecting multiple columns or multiple rows in this manner, remember that in your selection e.g.[1:5], the rows/columns selected will run from the first number to one minus the second number. e.g. [1:5] will go 1,2,3,4., [x,y] goes from x to y-1.
# In practice, I rarely use the iloc indexer, unless I want the first ( .iloc[0] ) or the last ( .iloc[-1] )  row of the data frame.

# %%
print (type(data.iloc[100]))# result of type series because only one row is selected
# Out:
# <class 'pandas.core.series.Series'>

# %%
print (type(data.iloc[[100]]))# result of type DataFrame because list selection is used
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print (type(data.iloc[2:10]))# result of type DataFrame since multiple row selection
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print (type(data.iloc[1:2, 3]))# series result because only one column selected
# Out:
# <class 'pandas.core.series.Series'>

# %%
print (type(data.iloc[1:2, [3]]))# dataFrame result with one column be one column selected
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print (type(data.iloc[1:2, 3:6])) # Dataframe result because multiple rows and columns selected
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ###### 2. Selecting pandas data using “loc”
# The Pandas loc indexer can be used with DataFrames for two different use cases:
#
# a.) Selecting rows by label/index
# b.) Selecting rows with a boolean / conditional lookup
# The loc indexer is used with the same syntax as iloc: data.loc[<row selection>, <column selection>] .

# %% [markdown]
# ###### 2a. Label-based / Index-based indexing using .loc
# Selections using the loc method are based on the index of the data frame (if any). Where the index is set on a DataFrame, using <code>df.set_index()</code>, the .loc method directly selects based on index values of any rows. For example, setting the index of our test data frame to the persons “last_name”:

# %%
data.set_index("last_name", inplace=True)

# %%
data.head(3)
# Out:
#            first_name             company_name       address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc  14 Taylor St
# Zigomalas        Evan       Cap Gemini America   5 Binney St
# Andrade        France      Elliott, John W Esq  8 Moor Place
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
#
#                   phone1        phone2                       email  \
# last_name
# Tomkiewicz  01835-703597  01944-369967     atomkiewicz@hotmail.com
# Zigomalas   01937-864715  01714-737668    evan.zigomalas@gmail.com
# Andrade     01347-368222  01935-821636  france.andrade@hotmail.com
#
#                                              web
# last_name
# Tomkiewicz  http://www.alandrosenburgcpapc.co.uk
# Zigomalas      http://www.capgeminiamerica.co.uk
# Andrade         http://www.elliottjohnwesq.co.uk

# %% [markdown]
# Now with the index set, we can directly select rows for different “last_name” values using .loc[<label>]  – either singly, or in multiples. For example:

# %%
data.loc['Andrade']
# Out:
# first_name                                France
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# email                 france.andrade@hotmail.com
# web             http://www.elliottjohnwesq.co.uk
# Name: Andrade, dtype: object

# %%
data.loc[['Andrade','Veness']]
# Out:
#           first_name         company_name            address  \
# last_name
# Andrade       France  Elliott, John W Esq       8 Moor Place
# Veness        Tyisha       Champagne Room  5396 Forth Street
#
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email  \
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                         web
# last_name
# Andrade    http://www.elliottjohnwesq.co.uk
# Veness       http://www.champagneroom.co.uk

# %% [markdown]
# ###### Selecting single or multiple rows using .loc index selections with pandas. Note that the first example returns a series, and the second returns a DataFrame. You can achieve a single-column DataFrame by passing a single-element list to the .loc operation.

# %%
print (type(data.loc['Andrade']))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Select columns with .loc using the names of the columns. In most of my data work, typically I have named columns, and use these named selections.

# %%
data.loc[['Andrade', 'Veness'], ['first_name','address','city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %% [markdown]
# You can select ranges of index labels – the selection </code>data.loc[‘Bruch’:’Julio’]</code> will return all rows in the data frame between the index entries for “Bruch” and “Julio”. The following examples should now make sense:

# %%
data.loc[['Andrade', 'Veness'], 'city':'email']
## Select rows with index values 'Andrade' and 'Veness', with all columns between 'city' and 'email'
# Out:
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com

# %%
# Select same rows, with just 'first_name', 'address' and 'city' columns
data.loc['Andrade':'Veness', ['first_name', 'address', 'city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Mcwalters    Ulysses      505 Exeter Rd              Hawerby cum Beesby
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
# Change the index to be based on the 'id' column
data.reset_index('id', inplace=True)

# %%
data.loc[487]
# Out:
# last_name                                             Kono
# first_name                                        Isabelle
# company_name                  Rock Springs Petroleum Equip
# address                                 4920 Fazakerley Rd
# city                               Plymstock Dunstone Ward
# county                                               Devon
# postal                                             PL9 8RD
# phone1                                        01552-682601
# phone2                                        01953-816728
# email                              isabelle.kono@yahoo.com
# web             http://www.rockspringspetroleumequip.co.uk
# Name: 487, dtype: object

# %%
data.tail()
# Out:
#     last_name first_name                    company_name             address  \
# 495      Veit      Avery      Plaza Gourmet Delicatessen  9166 Devon St #905
# 496   Euresti       Reid            Fitzgerald, Edward J        70 Foster St
# 497  Brenning  Charlette              Furey & Associates     714 Fonthill Rd
# 498     Keeny  Celestina        Bfg Federal Credit Union         9 Milton St
# 499    Richan         Mi  Nelson Wright Haworth Golf Crs     6 Norwood Grove
#
#                                city           county    postal        phone1  \
# 495  Knightsbridge and Belgravia Wa   Greater London  SW1W 8JY  01748-625058
# 496        Inverness Ness-Side Ward         Highland   IV2 6WT  01916-963261
# 497                Darton West Ward  South Yorkshire   S75 5EJ  01888-152110
# 498                Consett North ED    County Durham   DH8 5LP  01877-379681
# 499               Tanworth-in-Arden     Warwickshire   B94 5RZ  01451-785624
#
#            phone2                      email  \
# 495  01369-185737           avery@veit.co.uk
# 496  01370-319414     reuresti@euresti.co.uk
# 497  01301-312487   cbrenning@brenning.co.uk
# 498  01600-463475  celestina_keeny@gmail.com
# 499  01202-738406             mi@hotmail.com
#
#                                              web
# 495    http://www.plazagourmetdelicatessen.co.uk
# 496           http://www.fitzgeraldedwardj.co.uk
# 497             http://www.fureyassociates.co.uk
# 498       http://www.bfgfederalcreditunion.co.uk
# 499  http://www.nelsonwrighthaworthgolfcrs.co.uk

# %% [markdown]
# Note that in the last example, data.loc[487] (the row with index value 487) is not equal to data.iloc[487] (the 487th row in the data). The index of the DataFrame can be out of numeric order, and/or a string or multi-value.

# %%
data.iloc[487]
# Out:
# last_name                                             Kono
# first_name                                        Isabelle
# company_name                  Rock Springs Petroleum Equip
# address                                 4920 Fazakerley Rd
# city                               Plymstock Dunstone Ward
# county                                               Devon
# postal                                             PL9 8RD
# phone1                                        01552-682601
# phone2                                        01953-816728
# email                              isabelle.kono@yahoo.com
# web             http://www.rockspringspetroleumequip.co.uk
# Name: 487, dtype: object

# %% [markdown]
# ###### 2b. Boolean / Logical indexing using .loc
# Conditional selections with boolean arrays using data.loc[<selection>] is the most common method that I use with Pandas DataFrames. With boolean indexing or logical selection, you pass an array or Series of True/False values to the .loc indexer to select the rows where your Series has True values.
#
# In most use cases, you will make selections based on the values of different columns in your data set.
#
# For example, the statement data[‘first_name’] == ‘Antonio’] produces a Pandas Series with a True/False value for every row in the ‘data’ DataFrame, where there are “True” values for the rows where the first_name is “Antonio”. These type of boolean arrays can be passed directly to the .loc indexer as so:

# %% [markdown]
# ###### Select columns with .loc using the names of the columns. In most of my data work, typically I have named columns, and use these named selections.

# %%
data.loc[data['first_name']== 'Antonio']
# Out:
#       last_name first_name            company_name                address  \
# 272  Villamarin    Antonio        Combs Sheetmetal  353 Standish St #8264
# 285    Glasford    Antonio  Saint Thomas Creations          425 Howley St
# 427      Heilig    Antonio    Radisson Suite Hotel         35 Elton St #3
#
#                                city         county    postal        phone1  \
# 272  Little Parndon and Hare Street  Hertfordshire  CM20 2HT  01559-403415
# 285                  Gaer Community        Newport  NP20 3DE  01463-409090
# 427                        Ipplepen          Devon  TQ12 5LL  01324-171614
#
#            phone2                            email  \
# 272  01388-777812     antonio.villamarin@gmail.com
# 285  01242-318420  antonio_glasford@glasford.co.uk
# 427  01442-946357         antonio.heilig@gmail.com
#
#                                        web
# 272       http://www.combssheetmetal.co.uk
# 285  http://www.saintthomascreations.co.uk
# 427    http://www.radissonsuitehotel.co.uk

# %% [markdown]
# ###### Using a boolean True/False series to select rows in a pandas data frame – all rows with first name of “Antonio” are selected.

# %%
data.loc[data['first_name']== 'Erasmo',['company_name','email','phone1']]
# Out:
#            company_name                         email        phone1
# 233  Active Air Systems  erasmo.talentino@hotmail.com  01492-454455
# 393            Pan Optx             egath@hotmail.com  01445-796544
# 474    Martin Morrissey       erasmo_rhea@hotmail.com  01507-386397

# %%
data[['company_name','email','phone1']][data['first_name'] == 'Erasmo']# same as above
# Out:
#            company_name                         email        phone1
# 233  Active Air Systems  erasmo.talentino@hotmail.com  01492-454455
# 393            Pan Optx             egath@hotmail.com  01445-796544
# 474    Martin Morrissey       erasmo_rhea@hotmail.com  01507-386397

# %% [markdown]
# Selecting multiple columns with loc can be achieved by passing column names to the second argument of .loc[]

# %% [markdown]
# Note that when selecting columns, if one column only is selected, the .loc operator returns a Series. For a single column DataFrame, use a one-element list to keep the DataFrame format, for example:

# %%
data.loc[data['first_name']== 'Antonio', 'email']#.loc <selection> return a series- omitting the square bracket return a series
# Out:
# 272       antonio.villamarin@gmail.com
# 285    antonio_glasford@glasford.co.uk
# 427           antonio.heilig@gmail.com
# Name: email, dtype: object

# %%
print(type(data.loc[data['first_name']== 'Antonio', 'email']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data.loc[data['first_name']== 'Antonio', ['email']]#.loc <selection> return a DataFrame
# Out:
#                                email
# 272     antonio.villamarin@gmail.com
# 285  antonio_glasford@glasford.co.uk
# 427         antonio.heilig@gmail.com

# %%
print(type(data.loc[data['first_name']== 'Antonio', ['email']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ###### If selections of a single column are made as a string, a series is returned from .loc. Pass a list to get a DataFrame back.

# %%
# Select rows with first name Antonio, # and all columns between 'city' and 'email'
data.loc[data['first_name'] == 'Antonio', 'city':'email']
# Out:
#                                city         county    postal        phone1  \
# 272  Little Parndon and Hare Street  Hertfordshire  CM20 2HT  01559-403415
# 285                  Gaer Community        Newport  NP20 3DE  01463-409090
# 427                        Ipplepen          Devon  TQ12 5LL  01324-171614
#
#            phone2                            email
# 272  01388-777812     antonio.villamarin@gmail.com
# 285  01242-318420  antonio_glasford@glasford.co.uk
# 427  01442-946357         antonio.heilig@gmail.com

# %%
# Select rows where the email column ends with 'hotmail.com', include all columns
data.loc[data['email'].str.endswith("hotmail.com")]
# Out:
#          last_name  first_name                    company_name  \
# 0       Tomkiewicz     Aleshia         Alan D Rosenburg Cpa Pc
# 2          Andrade      France             Elliott, John W Esq
# 3        Mcwalters     Ulysses                  Mcmahan, Ben L
# 4           Veness      Tyisha                  Champagne Room
# 6         Grasmick        Marg   Wrangle Hill Auto Auct & Slvg
# 8         Manzella        Lura                 Bizerba Usa Inc
# 17           Julio      Dewitt            Rittenhouse Motor Co
# 24           Sitra        Tess                     Smart Signs
# 31          Zelaya      German   Jackson & Heit Machine Co Inc
# 33             Ear        Luis        Wa Inst For Plcy Studies
# 34         Cobbley       Ciara                   Wmgl 101.7 Fm
# 35           Mould     Alethea            Hughlett, Henry T Jr
# 38         Rawicki     Vicente   B & S Tool And Cutter Svc Inc
# 39             Cua       Craig               Berry, John M Esq
# 40           Dulle      Jenise            Alden, Michael H Esq
# 43     Bunselmeyer      Annett               Guynes Design Inc
# 51         Sandlin   Domonique          Marketing Horizons Inc
# 58          Kamens     Chantay       Brewster Wallcoverings Co
# 67          Ferenz     Stefany              L & L Sales Co Inc
# 71          Rubano     Wendell      Automation Engrg & Mfg Inc
# 409        http://www.audreymborlandstudios.co.uk
# 410              http://www.mayotimothylesq.co.uk
# 414         http://www.dankabusinesssystems.co.uk
# 417   http://www.daviscommercialcontracting.co.uk
# 419     http://www.smtothbaldridgevanbelkum.co.uk
# 425         http://www.oldencameralenscoinc.co.uk
# 429               http://www.elhispanicnews.co.uk
# 430         http://www.southbldgcodecongres.co.uk
# 433        http://www.bestwesterncaprockinn.co.uk
# 441     http://www.afsuplcodivautomtcfiring.co.uk
# 442     http://www.murraywhisnantarchitects.co.uk
# 445         http://www.waltonscarsongardens.co.uk
# 447                   http://www.prgcompany.co.uk
# 448   http://www.medlabenvironmentaltestinc.co.uk
# 452      http://www.masoninsuranceagencyinc.co.uk
# 455                  http://www.lookinggood.co.uk
# 459     http://www.williamagepperttruevalue.co.uk
# 461          http://www.creativeconsultants.co.uk
# 464                 http://www.malepowerltd.co.uk
# 465              http://www.atcpowersystems.co.uk
# 469                     http://www.microlan.co.uk
# 474              http://www.martinmorrissey.co.uk
# 475                http://www.autobodycolor.co.uk
# 476               http://www.fredanthonyesq.co.uk
# 477         http://www.advantagebookkeeping.co.uk
# 486                http://www.tcesystemsinc.co.uk
# 490               http://www.jurdemscottesq.co.uk
# 491                 http://www.lindnerfunds.co.uk
# 492             http://www.donaldgnelsonesq.co.uk
# 499   http://www.nelsonwrighthaworthgolfcrs.co.uk
#
# [114 rows x 11 columns]

# %%
# Select rows with last_name equal to some values, all columns
data.loc[data['first_name'].isin(['France', 'Tyisha', 'Eric'])]
# Out:
#   last_name first_name             company_name            address  \
# 2   Andrade     France      Elliott, John W Esq       8 Moor Place
# 4    Veness     Tyisha           Champagne Room  5396 Forth Street
# 5     Rampy       Eric  Thompson, Michael C Esq       9472 Lind St
#
#                              city            county    postal        phone1  \
# 2  East Southbourne and Tuckton W       Bournemouth   BH6 3BE  01347-368222
# 4      Greets Green and Lyng Ward     West Midlands   B70 9DT  01547-429341
# 5                      Desborough  Northamptonshire  NN14 2GH  01969-886290
#
#          phone2                       email  \
# 2  01935-821636  france.andrade@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
# 5  01545-817375          erampy@rampy.co.uk
#
#                                     web
# 2      http://www.elliottjohnwesq.co.uk
# 4        http://www.champagneroom.co.uk
# 5  http://www.thompsonmichaelcesq.co.uk

# %%
# Select rows with first name Antonio AND hotmail email addresses
data.loc[data['email'].str.endswith("gmail.com") & (data['first_name'] == 'Antonio')]
# Out:
#       last_name first_name          company_name                address  \
# 272  Villamarin    Antonio      Combs Sheetmetal  353 Standish St #8264
# 427      Heilig    Antonio  Radisson Suite Hotel         35 Elton St #3
#
#                                city         county    postal        phone1  \
# 272  Little Parndon and Hare Street  Hertfordshire  CM20 2HT  01559-403415
# 427                        Ipplepen          Devon  TQ12 5LL  01324-171614
#
#            phone2                         email  \
# 272  01388-777812  antonio.villamarin@gmail.com
# 427  01442-946357      antonio.heilig@gmail.com
#
#                                      web
# 272     http://www.combssheetmetal.co.uk
# 427  http://www.radissonsuitehotel.co.uk

# %%
# select rows with id column between 100 and 200, and just return 'postal' and 'web' columns
#data.loc[(data['id'] > 100) & (data['id'] <= 200), ['postal', 'web']] 
DOES NOT WORK
# Out:
#   File "<ipython-input-259-66cf40fa0525>", line 3
#     DOES NOT WORK
#            ^
# SyntaxError: invalid syntax

# %%
# A lambda function that yields True/False values can also be used.
# Select rows where the company name has 4 words in it.
data.loc[data['company_name'].apply(lambda x: len(x.split(' ')) == 4)]
# Out:
#          last_name   first_name                   company_name  \
# 2          Andrade       France            Elliott, John W Esq
# 5            Rampy         Eric        Thompson, Michael C Esq
# 11             Erm  Charlesetta               Cain, John M Esq
# 15       Throssell      Michell            Weiss Spirt & Guyer
# 16           Kanne        Edgar          Crowan, Kenneth W Esq
# 19        Lapinski          Mee       Galloway Electric Co Inc
# 20       Gutierres        Peter     Niagara Custombuilt Mfg Co
# 22         Teplica       Martha         Curtin, Patricia M Esq
# 23          Veigel      Tamesha            Wilhelm, James E Jr
# 25          Kufner      Leonard   Arctic Star Distributing Inc
# 26          Tauras     Svetlana       Lensbower, Gregory L Esq
# 29          Quarto        Karma                J C S Machinery
# 30       Weisinger         Reed           Berick, Joseph G Esq
# 32         Savidge        Milly      Bridgeway Plan For Health
# 35           Mould      Alethea           Hughlett, Henry T Jr
# 36       Loperfido    Margurite     Penrose Place Pharmacy Inc
# 37        Sperazza      Vernice           Novak, Alan Paul Esq
# 39             Cua        Craig              Berry, John M Esq
# 40           Dulle       Jenise           Alden, Michael H Esq
# 45        Orizabal       Melina       Sheraton Inn Ocean Front
# 46         Clapham         Tina              Cooper Myers Y Co
# 49       Kunimitsu       Carrol                Kisc 98 Kiss Fm
# 50         Mosseri         Alba       Schwartzbard, Gail L Esq
# 52       Neufville         Rory              Brady, Brad J Esq
# 57           Salta      Justine     Barajas & Bustamante Archl
# 59          Chisum      Tequila         Bohs Well Drilling Inc
# 60      Consolazio     Maybelle               Gavin, Lee W Esq
# 61           Bairo    Margarett           Reid, Carleton B Esq
# 65           Yadao      Lindsay        Lutz, Christopher T Esq
# 72     Stifflemire       Stevie      Packaging Corp Of America
# ..             ...          ...                            ...
# 413          Plues       Shelia            Schen, Sanford E Md
# 415          Frede      Evelynn      Hasselberg, Michael R Esq
# 418        Maricle        Dusti          Garton, Jeffrey P Esq
# 421      Stackpole        Leana       Direct Tools & Fasteners
# 422          Homer          Man       Applied Robotic Tech Inc
# 424          Naomi      Arletta                    E Zaks & Co
# 426            Pao         Nell            Madaus, Gerald F Jr
# 430          Hoyal       Alayna        South Bldg Code Congres
# 433           Saik        Royce       Best Western Caprock Inn
# 434         Sorrel     Cherelle           Wiltgen, Nancy A Esq
# 435      Dibartolo       Dudley         Mcknight, H Vincent Jr
# 436         Aldaco       Nettie           Miller Searl & Fitch
# 437         Bulcao      Carline          Brenner, Steven G Esq
# 440          Study      Lovetta        Borton Petrini & Conron
# 444         Farrin         Paul            Dering, James E Esq
# 446        Bowhall          Ona             Cohen And Fromm Pc
# 448  Schellenberge        Vicky  Medlab Environmental Test Inc
# 450    Adelsperger        Rusty            Clarke, James H Esq
# 452         Gesell     Teresita     Mason Insurance Agency Inc
# 487               isabelle.kono@yahoo.com
# 492                    elbert@hotmail.com
# 498             celestina_keeny@gmail.com
#
#                                              web
# 2               http://www.elliottjohnwesq.co.uk
# 5           http://www.thompsonmichaelcesq.co.uk
# 11                 http://www.cainjohnmesq.co.uk
# 15              http://www.weissspirtguyer.co.uk
# 16            http://www.crowankennethwesq.co.uk
# 19        http://www.gallowayelectriccoinc.co.uk
# 20      http://www.niagaracustombuiltmfgco.co.uk
# 22           http://www.curtinpatriciamesq.co.uk
# 23              http://www.wilhelmjamesejr.co.uk
# 25    http://www.arcticstardistributinginc.co.uk
# 26         http://www.lensbowergregorylesq.co.uk
# 29                 http://www.jcsmachinery.co.uk
# 30             http://www.berickjosephgesq.co.uk
# 32       http://www.bridgewayplanforhealth.co.uk
# 35             http://www.hughletthenrytjr.co.uk
# 36      http://www.penroseplacepharmacyinc.co.uk
# 37             http://www.novakalanpaulesq.co.uk
# 39                http://www.berryjohnmesq.co.uk
# 40             http://www.aldenmichaelhesq.co.uk
# 45        http://www.sheratoninnoceanfront.co.uk
# 46               http://www.coopermyersyco.co.uk
# 49                   http://www.kisckissfm.co.uk
# 50         http://www.schwartzbardgaillesq.co.uk
# 52                http://www.bradybradjesq.co.uk
# 57       http://www.barajasbustamantearchl.co.uk
# 59          http://www.bohswelldrillinginc.co.uk
# 60                 http://www.gavinleewesq.co.uk
# 61             http://www.reidcarletonbesq.co.uk
# 65          http://www.lutzchristophertesq.co.uk
# 72       http://www.packagingcorpofamerica.co.uk
# ..                                           ...
# 413             http://www.schensanfordemd.co.uk
# 415       http://www.hasselbergmichaelresq.co.uk
# 418           http://www.gartonjeffreypesq.co.uk
# 421        http://www.directtoolsfasteners.co.uk
# 422       http://www.appliedrobotictechinc.co.uk
# 424                     http://www.ezaksco.co.uk
# 426             http://www.madausgeraldfjr.co.uk
# 430        http://www.southbldgcodecongres.co.uk
# 433       http://www.bestwesterncaprockinn.co.uk
# 434            http://www.wiltgennancyaesq.co.uk
# 435          http://www.mcknighthvincentjr.co.uk
# 436            http://www.millersearlfitch.co.uk
# 437           http://www.brennerstevengesq.co.uk
# 440         http://www.bortonpetriniconron.co.uk
# 444             http://www.deringjameseesq.co.uk
# 446             http://www.cohenandfrommpc.co.uk
# 448  http://www.medlabenvironmentaltestinc.co.uk
# 450             http://www.clarkejameshesq.co.uk
# 452     http://www.masoninsuranceagencyinc.co.uk
# 453              http://www.jtpaintingcorp.co.uk
# 457             http://www.ciociajamesaesq.co.uk
# 460      http://www.hardwarespecialtycoinc.co.uk
# 467         http://www.goldbergstephenmesq.co.uk
# 473           http://www.millerwilliameiii.co.uk
# 480          http://www.schwartzthomaseesq.co.uk
# 481   http://www.allianceconstructioncoinc.co.uk
# 484           http://www.greatclipsforhair.co.uk
# 487   http://www.rockspringspetroleumequip.co.uk
# 492            http://www.donaldgnelsonesq.co.uk
# 498       http://www.bfgfederalcreditunion.co.uk
#
# [192 rows x 11 columns]

# %%
# Selections can be achieved outside of the main .loc for clarity:
# Form a separate variable with your selections:
idx = data['company_name'].apply(lambda x: len(x.split(' ')) == 4)
idx
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15      True
# 16      True
# 17     False
# 18     False
# 19      True
# 20      True
# 21     False
# 22      True
# 23      True
# 24     False
# 25      True
# 26      True
# 27     False
# 28     False
# 29      True
#        ...
# 470    False
# 471    False
# 472    False
# 473     True
# 474    False
# 475    False
# 476    False
# 477    False
# 478    False
# 479    False
# 480     True
# 481     True
# 482    False
# 483    False
# 484     True
# 485    False
# 486    False
# 487     True
# 488    False
# 489    False
# 490    False
# 491    False
# 492     True
# 493    False
# 494    False
# 495    False
# 496    False
# 497    False
# 498     True
# 499    False
# Name: company_name, dtype: bool

# %%
# Select only the True values in 'idx' and only the 3 columns specified:
data.loc[idx, ['email', 'first_name', 'company']]
# Out:
#                                     email   first_name  company
# 2              france.andrade@hotmail.com       France      NaN
# 5                      erampy@rampy.co.uk         Eric      NaN
# 11              charlesetta_erm@gmail.com  Charlesetta      NaN
# 15             mthrossell@throssell.co.uk      Michell      NaN
# 16                  edgar.kanne@yahoo.com        Edgar      NaN
# 19                 mee.lapinski@yahoo.com          Mee      NaN
# 20              peter_gutierres@yahoo.com        Peter      NaN
# 22                 mteplica@teplica.co.uk       Martha      NaN
# 23                   tveigel@veigel.co.uk      Tamesha      NaN
# 25                   lkufner@kufner.co.uk      Leonard      NaN
# 26           svetlana_tauras@tauras.co.uk     Svetlana      NaN
# 29                      kquarto@gmail.com        Karma      NaN
# 30               reed_weisinger@yahoo.com         Reed      NaN
# 32                        milly@gmail.com        Milly      NaN
# 35                    alethea@hotmail.com      Alethea      NaN
# 36                   mloperfido@gmail.com    Margurite      NaN
# 37                      vernice@yahoo.com      Vernice      NaN
# 39                      craig@hotmail.com        Craig      NaN
# 40               jenise.dulle@hotmail.com       Jenise      NaN
# 45                       melina@gmail.com       Melina      NaN
# 46                     tclapham@gmail.com         Tina      NaN
# 49             carrol_kunimitsu@yahoo.com       Carrol      NaN
# 50                         alba@gmail.com         Alba      NaN
# 52         rory_neufville@neufville.co.uk         Rory      NaN
# 57                justine_salta@yahoo.com      Justine      NaN
# 59            tequila.chisum@chisum.co.uk      Tequila      NaN
# 60                  mconsolazio@yahoo.com     Maybelle      NaN
# 61                    margarett@gmail.com    Margarett      NaN
# 65              lindsay_yadao@yadao.co.uk      Lindsay      NaN
# 72   stevie_stifflemire@stifflemire.co.uk       Stevie      NaN
# ..                                    ...          ...      ...
# 413                      shelia@gmail.com       Shelia      NaN
# 415               evelynn.frede@gmail.com      Evelynn      NaN
# 418                       dusti@gmail.com        Dusti      NaN
# 421                  lstackpole@yahoo.com        Leana      NaN
# 422                   man.homer@gmail.com          Man      NaN
# 424             arletta_naomi@naomi.co.uk      Arletta      NaN
# 426                        npao@gmail.com         Nell      NaN
# 430              alayna_hoyal@hotmail.com       Alayna      NaN
# 433                     royce@hotmail.com        Royce      NaN
# 434             cherelle_sorrel@gmail.com     Cherelle      NaN
# 435            dudley_dibartolo@yahoo.com       Dudley      NaN
# 436               nettie.aldaco@yahoo.com       Nettie      NaN
# 437                     carline@yahoo.com      Carline      NaN
# 440                   lovetta@study.co.uk      Lovetta      NaN
# 444              paul.farrin@farrin.co.uk         Paul      NaN
# 446                         ona@yahoo.com          Ona      NaN
# 448            vschellenberge@hotmail.com        Vicky      NaN
# 450           rusty.adelsperger@yahoo.com        Rusty      NaN
# 452           teresita_gesell@hotmail.com     Teresita      NaN
# 453             evangelina.gius@yahoo.com   Evangelina      NaN
# 457                    domitila@gmail.com     Domitila      NaN
# 460                  carlton@blyler.co.uk      Carlton      NaN
# 467                  peggy.khov@gmail.com        Peggy      NaN
# 473  isabella_piatkowski@piatkowski.co.uk     Isabella      NaN
# 480            tijuana.machalek@gmail.com      Tijuana      NaN
# 481               ahmad.alsaqri@yahoo.com        Ahmad      NaN
# 484          jacquelyne_reibman@yahoo.com   Jacquelyne      NaN
# 487               isabelle.kono@yahoo.com     Isabelle      NaN
# 492                    elbert@hotmail.com       Elbert      NaN
# 498             celestina_keeny@gmail.com    Celestina      NaN
#
# [192 rows x 3 columns]

# %%
# ix indexing works just the same as .loc when passed strings
data.ix[['Andrade']] == data.loc[['Andrade']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-267-82be456fb2b3> in <module>()
#       1 # ix indexing works just the same as .loc when passed strings
# ----> 2 data.ix[['Andrade']] == data.loc[['Andrade']]
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1454                     raise ValueError('Cannot index with multidimensional key')
#    1455
# -> 1456                 return self._getitem_iterable(key, axis=axis)
#    1457
#    1458             # nested tuple slicing
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1020     def _getitem_iterable(self, key, axis=0):
#    1021         if self._should_validate_iterable(axis):
# -> 1022             self._has_valid_type(key, axis)
#    1023
#    1024         labels = self.obj._get_axis(axis)
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1377
#    1378                 raise KeyError("None of [%s] are in the [%s]" %
# -> 1379                                (key, self.obj._get_axis_name(axis)))
#    1380
#    1381             return True
#
# KeyError: "None of [['Andrade']] are in the [index]"

# %%
# ix indexing works the same as .iloc when passed integers.
data.ix[[33]] == data.iloc[[33]]
# Out:
#    last_name first_name company_name address  city county postal phone1  \
# 33      True       True         True    True  True   True   True   True
#
#    phone2 email   web
# 33   True  True  True

# %% [markdown]
# ###### Setting values in DataFrames using .loc
# With a slight change of syntax, you can actually update your DataFrame in the same statement as you select and filter using .loc indexer. This particular pattern allows you to update values in columns depending on different conditions. The setting operation does not make a copy of the data frame, but edits the original data.
#
# As an example:

# %%
# Change the first name of all rows with an ID greater than 2000 to "John"
data.loc[data['id'] > 2000, "first_name"] = "John"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-272-cfa6294cc5b7> in <module>()
#       1 # Change the first name of all rows with an ID greater than 2000 to "John"
# ----> 2 data.loc[data['id'] > 2000, "first_name"] = "John"
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'id'

# %%
# Change the first name of all rows with an ID greater than 2000 to "John"
data.loc[data['id'] > 2000, "first_name"] = "John"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'idx'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-270-2d6788b64d37> in <module>()
#       1 # Change the first name of all rows with an ID greater than 2000 to "John"
# ----> 2 data.loc[data['idx'] > 2000, "first_name"] = "John"
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/sureshreemul/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'idx'
